# %% [markdown]
# # Qwen3-TTS Voice Mimic Edition (Colab)
#
# 這個 Notebook 會從 GitHub 拉取專案，安裝依賴後啟動 Gradio 介面

# %%
# !git clone https://github.com/pingqLIN/qwen3-tts-voice-mimic.git
# %cd qwen3-tts-voice-mimic

# %%
# !pip install -U pip
# !pip install -r requirements.txt

# %%
# !python app.py
